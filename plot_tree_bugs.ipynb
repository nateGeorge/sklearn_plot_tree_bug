# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('prepped_diabetes_data.csv', index_col='Patient number')
df
# Out:
#                 Cholesterol  Glucose  HDL Chol  Age  Gender  Height  Weight  \
# Patient number
# 1                       193       77        49   19       1      61     119
# 2                       146       79        41   19       1      60     135
# 3                       217       75        54   20       1      67     187
# 4                       226       97        70   20       1      64     114
# 5                       164       91        67   20       1      70     141
# ...                     ...      ...       ...  ...     ...     ...     ...
# 386                     227      105        44   83       1      59     125
# 387                     226      279        52   84       1      60     192
# 388                     301       90       118   89       1      61     115
# 389                     232      184       114   91       1      61     127
# 390                     165       94        69   92       1      62     217
#
# ...

# %%
features = df.drop('Diabetes', axis=1)
targets = df['Diabetes']

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(features, targets)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# saved figure is squished to the bottom left if dpi is increased
f = plt.figure(figsize=(10, 10))
plot_tree(dt, fontsize=8, feature_names=features.columns, filled=True)
plt.savefig('decision_tree.jpg', dpi=300)
plt.show()

# %%
dt = DecisionTreeClassifier(max_depth=5)
dt.fit(features, targets)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %% [markdown]
# With certain combinations of figsize, fontsize, and max_depth in the original tree, some arrows are shortened:

# %%
f = plt.figure(figsize=(14, 14))
_ = plot_tree(dt, fontsize=6, filled=True)
plt.show()
